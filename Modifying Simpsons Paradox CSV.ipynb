# %%
import numpy as np
import pandas as pd
import scipy

import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv('simpsons_paradox.csv')

# %%
df
# Out:
#     Gender  Mean_Age  Admitted  Rejected Department
# 0   Female        25        89        19          A
# 1   Female        22        17         8          B
# 2   Female        24       202       391          C
# 3   Female        23       131       244          D
# 4   Female        24        94       299          E
# 5   Female        24        24       317          F
# 6     Male        22       512       313          A
# 7     Male        22       353       207          B
# 8    Male         23       120       205          C
# 9    Male         24       138       279          D
# 10   Male         22        53       138          E
# 11   Male         25        22       351          F

# %%
df['Total Applicants'] = df['Admitted']+df['Rejected']

# %%
df['Acceptance Rate'] = df['Admitted']/df['Total Applicants']

# %%
df
# Out:
#     Gender  Mean_Age  Admitted  Rejected Department  Total Applicants  \
# 0   Female        25        89        19          A               108
# 1   Female        22        17         8          B                25
# 2   Female        24       202       391          C               593
# 3   Female        23       131       244          D               375
# 4   Female        24        94       299          E               393
# 5   Female        24        24       317          F               341
# 6     Male        22       512       313          A               825
# 7     Male        22       353       207          B               560
# 8    Male         23       120       205          C               325
# 9    Male         24       138       279          D               417
# 10   Male         22        53       138          E               191
# 11   Male         25        22       351          F               373
#
#     Acceptance Rate
# 0          0.824074
# ...

# %%
df.to_csv('Simpsons_Paradox_Cleaned.csv')
